# %% [markdown]
# <a href="https://colab.research.google.com/github/IndraLukasTjahaja/Speech_Text/blob/main/DeepSpeech_train_a_model%2C_CV_Indonesia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tutorial: Training a Indonesia speech-to-text model
# ## Using DeepSpeech and Common Voice, based on DeepSpeech 0.9.3
#
# ### Updated as of 5 May 2022
#
# *This tutorial based on https://colab.research.google.com/github/acabunoc/Tutorial-train-dutch-model/blob/master/DeepSpeech_train_a_model%2C_CV_Dutch.ipynb with revisions.*
#
# *If you would like to implement this in your local computer, you can follow the guideline here to prepare your system https://docs.google.com/document/d/1sg4bm6xx9ZJc4GVPaVpUAQJ4GyPHPMk1Jp5W_AfqjrE/edit?usp=sharing However I strongly suggest you to use cloud solutions. I spent a week trying to prepare the system and it was not successful as the complex combination of hardware/linux/python/dependencies/CUDA alywas conflict with one another*
#
# *In this tutorial, we're going to use Mozilla's DeepSpeech and Common Voice to train a Dutch speech-to-text model. The instructions are taken directly from the DeepSpeech documentation https://deepspeech.readthedocs.io/en/r0.9/TRAINING.html, linked in each section. Any changes from the docs or comments made will be writen in italics or highlighted in a comment on Colab*
#
# *This uses the free tier on Google Colab. I turned on GPU hardware accelerator in Notebook settings. I did not add any additional file storage.*

# %% [markdown]
# ##Training Your Own Model
# Taken from the [DeepSpeech docs - Training Your Own Model](https://deepspeech.readthedocs.io/en/v0.7.4/TRAINING.html#training-your-own-model)
#
# For new version of document: https://deepspeech.readthedocs.io/en/r0.9/TRAINING.html

# %% [markdown]
# ### Prerequisites for training a model
#
#
# * Python 3.6
# * CUDA 10.0 / CuDNN v7.6 per Dockerfile. (for local)
# * Mac or Linux environment (for local)
# * Git large file (for Google Colab)

# %%
# Checking Python version
# !python --version
import sys
sys.version
# Out:
# Python 3.7.13
# '3.7.13 (default, Apr 24 2022, 01:04:09) \n[GCC 7.5.0]'

# %%
# Downgrade to Python 3.6 as per the following guideline https://colab.research.google.com/github/Dene33/mlcourse.ai/blob/master/jupyter_english/tutorials/Useful_Google_Colab_snippets.ipynb
# Test whether 3.7 works or not

# %%
import sys
! sudo apt-get install git-lfs
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# git-lfs is already the newest version (2.3.4-1).
# The following packages were automatically installed and are no longer required:
#   libnvidia-common-460 nsight-compute-2020.2.0
# Use 'sudo apt autoremove' to remove them.
# 0 upgraded, 0 newly installed, 0 to remove and 42 not upgraded.

# %% [markdown]
# ### Get the training code
#
# Then clone the DeepSpeech repository and run `git lfs pull`.

# %%
! git clone https://github.com/mozilla/DeepSpeech --branch v0.9.3
# if error is fatal: destination path exist, then you already copy it to your GoogleColab
# Out:
# Cloning into 'DeepSpeech'...
# remote: Enumerating objects: 23888, done.
# remote: Total 23888 (delta 0), reused 0 (delta 0), pack-reused 23888
# Receiving objects: 100% (23888/23888), 49.36 MiB | 22.86 MiB/s, done.
# Resolving deltas: 100% (16417/16417), done.
# Note: checking out 'f2e9c85880dff94115ab510cde9ca4af7ee51c19'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by performing another checkout.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -b with the checkout command again. Example:
#
#   git checkout -b <new-branch-name>

# %%
# %cd /content/DeepSpeech
! git lfs pull
# Out:
# /content/DeepSpeech

# %% [markdown]
# ### Creating a virtual environment
#
# In creating a virtual environment you will create a directory containing a python3 binary and everything needed to run deepspeech. You can use whatever directory you want. For the purpose of the documentation, we will rely on $HOME/tmp/deepspeech-train-venv.

# %%
! pip3 install virtualenv
! virtualenv -p python3 $HOME/tmp/deepspeech-train-venv/
# Out:
# Collecting virtualenv
#   Downloading virtualenv-20.14.1-py2.py3-none-any.whl (8.8 MB)
#      |████████████████████████████████| 8.8 MB 14.4 MB/s
# Requirement already satisfied: importlib-metadata>=0.12 in /usr/local/lib/python3.7/dist-packages (from virtualenv) (4.11.3)
# Requirement already satisfied: filelock<4,>=3.2 in /usr/local/lib/python3.7/dist-packages (from virtualenv) (3.6.0)
# Requirement already satisfied: six<2,>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from virtualenv) (1.15.0)
# Collecting distlib<1,>=0.3.1
#   Downloading distlib-0.3.4-py2.py3-none-any.whl (461 kB)
#      |████████████████████████████████| 461 kB 68.4 MB/s
# Collecting platformdirs<3,>=2
#   Downloading platformdirs-2.5.2-py3-none-any.whl (14 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.12->virtualenv) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.12->virtualenv) (4.2.0)
# Installing collected packages: platformdirs, distlib, virtualenv
# Successfully installed distlib-0.3.4 platformdirs-2.5.2 virtualenv-20.14.1
# created virtual environment CPython3.7.13.final.0-64 in 753ms
#   creator CPython3Posix(dest=/root/tmp/deepspeech-train-venv, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, setuptools=bundle, wheel=bundle, via=copy, app_data_dir=/root/.local/share/virtualenv)
#     added seed packages: pip==22.0.4, setuptools==62.1.0, wheel==0.37.1
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator

# %% [markdown]
# Once this command completes successfully, the environment will be ready to be activated.

# %% [markdown]
# ####Activating the environment
#
# Each time you need to work with DeepSpeech, you have to activate this virtual environment. This is done with this simple command:

# %%
! source $HOME/tmp/deepspeech-train-venv/bin/activate

# %% [markdown]
# ### Installing DeepSpeech Training Code and its dependencies
#
# Install the required dependencies using pip3:

# %%
# %cd /content/DeepSpeech
! pip3 install --upgrade pip==20.2.2 wheel==0.34.2 setuptools==49.6.0
# Out:
# /content/DeepSpeech
# Collecting pip==20.2.2
#   Downloading pip-20.2.2-py2.py3-none-any.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 12.3 MB/s
# Collecting wheel==0.34.2
#   Downloading wheel-0.34.2-py2.py3-none-any.whl (26 kB)
# Collecting setuptools==49.6.0
#   Downloading setuptools-49.6.0-py3-none-any.whl (803 kB)
#      |████████████████████████████████| 803 kB 66.4 MB/s
# Installing collected packages: wheel, setuptools, pip
#   Attempting uninstall: wheel
#     Found existing installation: wheel 0.37.1
#     Uninstalling wheel-0.37.1:
#       Successfully uninstalled wheel-0.37.1
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 57.4.0
#     Uninstalling setuptools-57.4.0:
#       Successfully uninstalled setuptools-57.4.0
#   Attempting uninstall: pip
#     Found existing installation: pip 21.1.3
#     Uninstalling pip-21.1.3:
#       Successfully uninstalled pip-21.1.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.0 requires tf-estimator-nightly==2.8.0.dev2021122109, which is not installed.
# pip-tools 6.2.0 requires pip>=20.3, but you have pip 20.2.2 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed pip-20.2.2 setuptools-49.6.0 wheel-0.34.2

# %%
# %cd /content/DeepSpeech
! pip3 install --upgrade -e .
# Out:
# /content/DeepSpeech
# Obtaining file:///content/DeepSpeech
# Requirement already satisfied, skipping upgrade: numpy in /usr/local/lib/python3.7/dist-packages (from deepspeech-training==0.9.3) (1.21.6)
# Requirement already satisfied, skipping upgrade: progressbar2 in /usr/local/lib/python3.7/dist-packages (from deepspeech-training==0.9.3) (3.38.0)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.7/dist-packages (from deepspeech-training==0.9.3) (1.15.0)
# Collecting pyxdg
#   Downloading pyxdg-0.27-py2.py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 4.9 MB/s
# Collecting attrdict
#   Downloading attrdict-2.0.1-py2.py3-none-any.whl (9.9 kB)
# Requirement already satisfied, skipping upgrade: absl-py in /usr/local/lib/python3.7/dist-packages (from deepspeech-training==0.9.3) (1.0.0)
# Requirement already satisfied, skipping upgrade: semver in /usr/local/lib/python3.7/dist-packages (from deepspeech-training==0.9.3) (2.13.0)
# Collecting opuslib==2.0.0
#   Downloading opuslib-2.0.0.tar.gz (7.3 kB)
# Collecting optuna
#   Downloading optuna-2.10.0-py3-none-any.whl (308 kB)
#      |████████████████████████████████| 308 kB 28.4 MB/s
# Collecting sox
#   Downloading sox-1.4.1-py2.py3-none-any.whl (39 kB)
# Requirement already satisfied, skipping upgrade: bs4 in /usr/local/lib/python3.7/dist-packages (from deepspeech-training==0.9.3) (0.0.1)
# Requirement already satisfied, skipping upgrade: pandas in /usr/local/lib/python3.7/dist-packages (from deepspeech-training==0.9.3) (1.3.5)
# Requirement already satisfied, skipping upgrade: requests in /usr/local/lib/python3.7/dist-packages (from deepspeech-training==0.9.3) (2.23.0)
# Collecting numba==0.47.0
#   Downloading numba-0.47.0-cp37-cp37m-manylinux1_x86_64.whl (3.7 MB)
#      |████████████████████████████████| 3.7 MB 53.9 MB/s
# Collecting llvmlite==0.31.0
#   Downloading llvmlite-0.31.0-cp37-cp37m-manylinux1_x86_64.whl (20.2 MB)
#      |████████████████████████████████| 20.2 MB 1.2 MB/s
# Requirement already satisfied, skipping upgrade: librosa in /usr/local/lib/python3.7/dist-packages (from deepspeech-training==0.9.3) (0.8.1)
# Requirement already satisfied, skipping upgrade: soundfile in /usr/local/lib/python3.7/dist-packages (from deepspeech-training==0.9.3) (0.10.3.post1)
# Collecting ds_ctcdecoder==0.9.3
#   Downloading ds_ctcdecoder-0.9.3-cp37-cp37m-manylinux1_x86_64.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 45.5 MB/s
# Collecting tensorflow==1.15.4
#   Downloading tensorflow-1.15.4-cp37-cp37m-manylinux2010_x86_64.whl (110.5 MB)
#      |████████████████████████████████| 110.5 MB 1.2 MB/s
# Requirement already satisfied, skipping upgrade: python-utils>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from progressbar2->deepspeech-training==0.9.3) (3.1.0)
# Collecting colorlog
#   Downloading colorlog-6.6.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied, skipping upgrade: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from optuna->deepspeech-training==0.9.3) (21.3)
# Requirement already satisfied, skipping upgrade: sqlalchemy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from optuna->deepspeech-training==0.9.3) (1.4.36)
# Collecting alembic
#   Downloading alembic-1.7.7-py3-none-any.whl (210 kB)
#      |████████████████████████████████| 210 kB 77.1 MB/s
# Requirement already satisfied, skipping upgrade: scipy!=1.4.0 in /usr/local/lib/python3.7/dist-packages (from optuna->deepspeech-training==0.9.3) (1.4.1)
# Collecting cmaes>=0.8.2
#   Downloading cmaes-0.8.2-py3-none-any.whl (15 kB)
# Requirement already satisfied, skipping upgrade: tqdm in /usr/local/lib/python3.7/dist-packages (from optuna->deepspeech-training==0.9.3) (4.64.0)
# Collecting cliff
#   Downloading cliff-3.10.1-py3-none-any.whl (81 kB)
#      |████████████████████████████████| 81 kB 11.9 MB/s
# Requirement already satisfied, skipping upgrade: PyYAML in /usr/local/lib/python3.7/dist-packages (from optuna->deepspeech-training==0.9.3) (3.13)
# Requirement already satisfied, skipping upgrade: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from bs4->deepspeech-training==0.9.3) (4.6.3)
# Requirement already satisfied, skipping upgrade: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->deepspeech-training==0.9.3) (2022.1)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->deepspeech-training==0.9.3) (2.8.2)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->deepspeech-training==0.9.3) (1.24.3)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->deepspeech-training==0.9.3) (3.0.4)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->deepspeech-training==0.9.3) (2.10)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->deepspeech-training==0.9.3) (2021.10.8)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.7/dist-packages (from numba==0.47.0->deepspeech-training==0.9.3) (49.6.0)
# Requirement already satisfied, skipping upgrade: decorator>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa->deepspeech-training==0.9.3) (4.4.2)
# Requirement already satisfied, skipping upgrade: audioread>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa->deepspeech-training==0.9.3) (2.1.9)
# Requirement already satisfied, skipping upgrade: pooch>=1.0 in /usr/local/lib/python3.7/dist-packages (from librosa->deepspeech-training==0.9.3) (1.6.0)
# Requirement already satisfied, skipping upgrade: joblib>=0.14 in /usr/local/lib/python3.7/dist-packages (from librosa->deepspeech-training==0.9.3) (1.1.0)
# Requirement already satisfied, skipping upgrade: resampy>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from librosa->deepspeech-training==0.9.3) (0.2.2)
# Requirement already satisfied, skipping upgrade: scikit-learn!=0.19.0,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from librosa->deepspeech-training==0.9.3) (1.0.2)
# Requirement already satisfied, skipping upgrade: cffi>=1.0 in /usr/local/lib/python3.7/dist-packages (from soundfile->deepspeech-training==0.9.3) (1.15.0)
# Requirement already satisfied, skipping upgrade: google-pasta>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.4->deepspeech-training==0.9.3) (0.2.0)
# Requirement already satisfied, skipping upgrade: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.4->deepspeech-training==0.9.3) (3.3.0)
# Collecting tensorboard<1.16.0,>=1.15.0
#   Downloading tensorboard-1.15.0-py3-none-any.whl (3.8 MB)
#      |████████████████████████████████| 3.8 MB 54.9 MB/s
# Requirement already satisfied, skipping upgrade: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.4->deepspeech-training==0.9.3) (0.34.2)
# Collecting keras-applications>=1.0.8
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 3.4 MB/s
# Requirement already satisfied, skipping upgrade: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.4->deepspeech-training==0.9.3) (1.1.2)
# Requirement already satisfied, skipping upgrade: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.4->deepspeech-training==0.9.3) (1.1.0)
# Collecting gast==0.2.2
#   Downloading gast-0.2.2.tar.gz (10 kB)
# Requirement already satisfied, skipping upgrade: astor>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.4->deepspeech-training==0.9.3) (0.8.1)
# Collecting tensorflow-estimator==1.15.1
#   Downloading tensorflow_estimator-1.15.1-py2.py3-none-any.whl (503 kB)
#      |████████████████████████████████| 503 kB 67.7 MB/s
# Requirement already satisfied, skipping upgrade: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.4->deepspeech-training==0.9.3) (1.14.0)
# Requirement already satisfied, skipping upgrade: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.4->deepspeech-training==0.9.3) (1.44.0)
# Requirement already satisfied, skipping upgrade: protobuf>=3.6.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.4->deepspeech-training==0.9.3) (3.17.3)
# Requirement already satisfied, skipping upgrade: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->optuna->deepspeech-training==0.9.3) (3.0.8)
# Requirement already satisfied, skipping upgrade: greenlet!=0.4.17; python_version >= "3" and (platform_machine == "aarch64" or (platform_machine == "ppc64le" or (platform_machine == "x86_64" or (platform_machine == "amd64" or (platform_machine == "AMD64" or (platform_machine == "win32" or platform_machine == "WIN32")))))) in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.1.0->optuna->deepspeech-training==0.9.3) (1.1.2)
# Requirement already satisfied, skipping upgrade: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.1.0->optuna->deepspeech-training==0.9.3) (4.11.3)
# Requirement already satisfied, skipping upgrade: importlib-resources; python_version < "3.9" in /usr/local/lib/python3.7/dist-packages (from alembic->optuna->deepspeech-training==0.9.3) (5.7.1)
# Collecting Mako
#   Downloading Mako-1.2.0-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 9.9 MB/s
# Collecting autopage>=0.4.0
#   Downloading autopage-0.5.0-py3-none-any.whl (29 kB)
# Collecting stevedore>=2.0.1
#   Downloading stevedore-3.5.0-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 8.1 MB/s
# Collecting cmd2>=1.0.0
#   Downloading cmd2-2.4.1-py3-none-any.whl (146 kB)
#      |████████████████████████████████| 146 kB 80.1 MB/s
# Requirement already satisfied, skipping upgrade: PrettyTable>=0.7.2 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna->deepspeech-training==0.9.3) (3.2.0)
# Collecting pbr!=2.1.0,>=2.0.0
#   Downloading pbr-5.9.0-py2.py3-none-any.whl (112 kB)
#      |████████████████████████████████| 112 kB 80.2 MB/s
# Requirement already satisfied, skipping upgrade: appdirs>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from pooch>=1.0->librosa->deepspeech-training==0.9.3) (1.4.4)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa->deepspeech-training==0.9.3) (3.1.0)
# Requirement already satisfied, skipping upgrade: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0->soundfile->deepspeech-training==0.9.3) (2.21)
# Requirement already satisfied, skipping upgrade: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.4->deepspeech-training==0.9.3) (3.3.6)
# Requirement already satisfied, skipping upgrade: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.4->deepspeech-training==0.9.3) (1.0.1)
# Requirement already satisfied, skipping upgrade: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.8->tensorflow==1.15.4->deepspeech-training==0.9.3) (3.1.0)
# Requirement already satisfied, skipping upgrade: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->sqlalchemy>=1.1.0->optuna->deepspeech-training==0.9.3) (4.2.0)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->sqlalchemy>=1.1.0->optuna->deepspeech-training==0.9.3) (3.8.0)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.9.2 in /usr/local/lib/python3.7/dist-packages (from Mako->alembic->optuna->deepspeech-training==0.9.3) (2.0.1)
# Requirement already satisfied, skipping upgrade: attrs>=16.3.0 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna->deepspeech-training==0.9.3) (21.4.0)
# Requirement already satisfied, skipping upgrade: wcwidth>=0.1.7 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna->deepspeech-training==0.9.3) (0.2.5)
# Collecting pyperclip>=1.6
#   Downloading pyperclip-1.8.2.tar.gz (20 kB)
# Requirement already satisfied, skipping upgrade: cached-property; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from h5py->keras-applications>=1.0.8->tensorflow==1.15.4->deepspeech-training==0.9.3) (1.5.2)
# Building wheels for collected packages: opuslib, gast, pyperclip
#   Building wheel for opuslib (setup.py) ... done
#   Created wheel for opuslib: filename=opuslib-2.0.0-py3-none-any.whl size=11009 sha256=cb6eb994b337cba85036a7e20c72f4cef913997105adc06a203b4322840942ab
#   Stored in directory: /root/.cache/pip/wheels/e5/ba/d4/0e81231a9797fbb262ae3a54fd761fab850db7f32d94a3283a
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-py3-none-any.whl size=7539 sha256=b20060432384c513a05f840361debfdb59d22247ade38a44b1e524a9fcd18562
#   Stored in directory: /root/.cache/pip/wheels/21/7f/02/420f32a803f7d0967b48dd823da3f558c5166991bfd204eef3
#   Building wheel for pyperclip (setup.py) ... done
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11107 sha256=544e4b1fb77d988c44992b0326cff2be28f54f8653388fec2e53de969ef797f4
#   Stored in directory: /root/.cache/pip/wheels/9f/18/84/8f69f8b08169c7bae2dde6bd7daf0c19fca8c8e500ee620a28
# Successfully built opuslib gast pyperclip
# Installing collected packages: pyxdg, attrdict, opuslib, colorlog, Mako, alembic, cmaes, autopage, pbr, stevedore, pyperclip, cmd2, cliff, optuna, sox, llvmlite, numba, ds-ctcdecoder, tensorboard, keras-applications, gast, tensorflow-estimator, tensorflow, deepspeech-training
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.34.0
#     Uninstalling llvmlite-0.34.0:
#       Successfully uninstalled llvmlite-0.34.0
#   Attempting uninstall: numba
#     Found existing installation: numba 0.51.2
#     Uninstalling numba-0.51.2:
#       Successfully uninstalled numba-0.51.2
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
#       Successfully uninstalled tensorboard-2.8.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.3
#     Uninstalling gast-0.5.3:
#       Successfully uninstalled gast-0.5.3
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.8.0
#     Uninstalling tensorflow-estimator-2.8.0:
#       Successfully uninstalled tensorflow-estimator-2.8.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.8.0
#     Uninstalling tensorflow-2.8.0:
#       Successfully uninstalled tensorflow-2.8.0
#   Running setup.py develop for deepspeech-training
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# tensorflow 1.15.4 requires numpy<1.19.0,>=1.16.0, but you'll have numpy 1.21.6 which is incompatible.
# tensorflow-probability 0.16.0 requires gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.
# kapre 0.3.7 requires tensorflow>=2.0.0, but you'll have tensorflow 1.15.4 which is incompatible.
# Successfully installed Mako-1.2.0 alembic-1.7.7 attrdict-2.0.1 autopage-0.5.0 cliff-3.10.1 cmaes-0.8.2 cmd2-2.4.1 colorlog-6.6.0 deepspeech-training ds-ctcdecoder-0.9.3 gast-0.2.2 keras-applications-1.0.8 llvmlite-0.31.0 numba-0.47.0 optuna-2.10.0 opuslib-2.0.0 pbr-5.9.0 pyperclip-1.8.2 pyxdg-0.27 sox-1.4.1 stevedore-3.5.0 tensorboard-1.15.0 tensorflow-1.15.4 tensorflow-estimator-1.15.1

# %% [markdown]
# #### Recommendations
#
# If you have a capable (NVIDIA, at least 8GB of VRAM) GPU, it is highly recommended to install TensorFlow with GPU support. Training will be significantly faster than using the CPU. To enable GPU support, you can do:

# %%
! yes | pip3 uninstall tensorflow
! pip3 install 'tensorflow-gpu==1.15.4'
# Out:
# Found existing installation: tensorflow 1.15.4
# Uninstalling tensorflow-1.15.4:
#   Would remove:
#     /usr/local/bin/estimator_ckpt_converter
#     /usr/local/bin/freeze_graph
#     /usr/local/bin/saved_model_cli
#     /usr/local/bin/tensorboard
#     /usr/local/bin/tf_upgrade_v2
#     /usr/local/bin/tflite_convert
#     /usr/local/bin/toco
#     /usr/local/bin/toco_from_protos
#     /usr/local/lib/python3.7/dist-packages/tensorflow-1.15.4.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/tensorflow/*
#     /usr/local/lib/python3.7/dist-packages/tensorflow_core/*
# Proceed (y/n)?   Successfully uninstalled tensorflow-1.15.4
# Collecting tensorflow-gpu==1.15.4
#   Downloading tensorflow_gpu-1.15.4-cp37-cp37m-manylinux2010_x86_64.whl (411.0 MB)
#      |████████████████████████████████| 411.0 MB 26 kB/s
# Requirement already satisfied: tensorboard<1.16.0,>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.4) (1.15.0)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.4) (0.34.2)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.4) (0.2.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.4) (0.8.1)
# Requirement already satisfied: gast==0.2.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.4) (0.2.2)
# Collecting numpy<1.19.0,>=1.16.0
#   Downloading numpy-1.18.5-cp37-cp37m-manylinux1_x86_64.whl (20.1 MB)
#      |████████████████████████████████| 20.1 MB 1.3 MB/s
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.4) (1.1.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.4) (3.17.3)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.4) (1.44.0)
# Requirement already satisfied: tensorflow-estimator==1.15.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.4) (1.15.1)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.4) (1.0.8)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.4) (1.0.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.4) (1.1.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.4) (3.3.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.4) (1.15.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.15.4) (1.14.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.4) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.4) (3.3.6)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.4) (49.6.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.8->tensorflow-gpu==1.15.4) (3.1.0)
# Requirement already satisfied: importlib-metadata>=4.4; python_version < "3.10" in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.4) (4.11.3)
# Requirement already satisfied: cached-property; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from h5py->keras-applications>=1.0.8->tensorflow-gpu==1.15.4) (1.5.2)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4; python_version < "3.10"->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.4) (4.2.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4; python_version < "3.10"->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.4) (3.8.0)
# Installing collected packages: numpy, tensorflow-gpu
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.6
#     Uninstalling numpy-1.21.6:
#       Successfully uninstalled numpy-1.21.6
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# kapre 0.3.7 requires tensorflow>=2.0.0, which is not installed.
# deepspeech-training 0.9.3 requires tensorflow==1.15.4, which is not installed.
# tensorflow-probability 0.16.0 requires gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.
# tables 3.7.0 requires numpy>=1.19.0, but you'll have numpy 1.18.5 which is incompatible.
# jaxlib 0.3.7+cuda11.cudnn805 requires numpy>=1.19, but you'll have numpy 1.18.5 which is incompatible.
# jax 0.3.8 requires numpy>=1.19, but you'll have numpy 1.18.5 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Successfully installed numpy-1.18.5 tensorflow-gpu-1.15.4

# %% [markdown]
# ### Common Voice Training Data
# The Common Voice corpus consists of voice samples that were donated through Mozilla’s [Common Voice Initiative](https://voice.mozilla.org/). You can download individual CommonVoice v2.0 language data sets from [here](https://voice.mozilla.org/en/datasets). After extraction of such a data set, you’ll find the following contents:
#
# * the `*.tsv` files output by CorporaCreator for the downloaded language
# * the mp3 audio files they reference in a `clips` sub-directory.
#
# *To retrieve the Dutch dataset, I went to the [CommonVoice 2.0 language datasets](https://voice.mozilla.org/en/datasets), selected Dutch from the dropdown, provided my email then right-clicked to get the gz file.*

# %%
# %cd /content
# %mkdir in
# %cd in
! wget https://mozilla-common-voice-datasets.s3.dualstack.us-west-2.amazonaws.com/cv-corpus-9.0-2022-04-27/cv-corpus-9.0-2022-04-27-id.tar.gz
# Out:
# /content
# /content/in
# --2022-05-07 00:36:17--  https://mozilla-common-voice-datasets.s3.dualstack.us-west-2.amazonaws.com/cv-corpus-9.0-2022-04-27/cv-corpus-9.0-2022-04-27-id.tar.gz
# Resolving mozilla-common-voice-datasets.s3.dualstack.us-west-2.amazonaws.com (mozilla-common-voice-datasets.s3.dualstack.us-west-2.amazonaws.com)... 52.218.177.225, 2600:1fa0:406c:1109:34da:ed09::
# Connecting to mozilla-common-voice-datasets.s3.dualstack.us-west-2.amazonaws.com (mozilla-common-voice-datasets.s3.dualstack.us-west-2.amazonaws.com)|52.218.177.225|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1253048208 (1.2G) [application/octet-stream]
# Saving to: ‘cv-corpus-9.0-2022-04-27-id.tar.gz’
#
# cv-corpus-9.0-2022- 100%[===================>]   1.17G  17.8MB/s    in 70s
#
# 2022-05-07 00:37:27 (17.1 MB/s) - ‘cv-corpus-9.0-2022-04-27-id.tar.gz’ saved [1253048208/1253048208]

# %%
# %cd /content/in
! tar xvzf cv-corpus-9.0-2022-04-27-id.tar.gz
# Out:
# Streaming output truncated to the last 5000 lines.
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457844.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457845.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457846.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457847.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457848.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457849.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457859.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457860.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457861.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457862.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457863.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457864.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457865.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457866.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457867.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457868.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457869.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457870.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457871.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457872.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457873.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457874.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457875.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457876.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457877.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457878.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457879.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457880.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457881.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457882.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457883.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457884.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457885.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457886.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457887.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457888.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457889.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457890.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457891.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457892.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457893.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457894.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457895.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457896.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457897.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457898.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457899.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457900.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457901.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457902.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457903.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457904.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457905.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457906.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457907.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457908.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457909.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457910.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457911.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457912.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457913.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457914.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457915.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457916.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457917.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457918.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457919.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457920.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457926.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457927.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457928.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457929.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457930.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457931.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457932.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457933.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457934.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457935.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457941.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457942.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457943.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457944.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457945.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457946.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457947.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457948.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457949.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457950.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457956.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457957.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457958.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457959.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457961.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457962.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457963.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457964.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457965.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457966.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457967.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457968.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457969.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457970.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457976.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457977.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457978.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457979.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457980.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457981.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457982.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457983.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457984.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457985.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457986.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457987.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457988.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457989.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457990.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457996.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457997.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457998.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27457999.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458000.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458006.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458008.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458009.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458010.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458011.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458012.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458013.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458014.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458015.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458021.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458022.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458023.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458024.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458025.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458026.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458027.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458028.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458029.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458030.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458036.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458037.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458038.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458039.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458040.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458046.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458047.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458048.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458049.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458050.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458051.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458052.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458053.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458054.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458055.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458061.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458062.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458063.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458064.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458065.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458066.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458067.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458068.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458069.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458070.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458076.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458077.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458078.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458079.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458080.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458086.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458087.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458088.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458089.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458090.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458101.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458102.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458103.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458104.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458105.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458106.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458107.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458108.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458109.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458110.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458113.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458114.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458115.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458117.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27458118.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27459611.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27459612.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27459613.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27459614.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27459615.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27459636.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27459637.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27459638.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27459639.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27459640.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27459666.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27459667.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27459668.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27459669.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27459670.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27459696.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27459697.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27459698.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27459699.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27459701.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27461660.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27461661.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27461662.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27461663.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27461664.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27461689.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27461690.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27461692.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27461693.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27461696.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473146.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473147.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473148.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473149.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473150.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473161.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473162.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473163.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473164.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473165.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473176.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473177.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473178.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473179.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473180.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473181.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473182.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473183.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473184.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473185.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473661.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473662.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473663.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473664.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473665.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473679.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473681.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473683.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473684.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473685.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473750.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473751.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473752.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473753.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473754.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473780.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473781.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473782.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473783.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473784.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473805.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473806.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473807.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473808.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473809.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473815.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473816.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473817.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473818.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473819.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473825.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473826.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473827.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473828.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473829.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473840.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473841.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473842.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473843.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473844.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473850.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473851.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473852.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473853.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473854.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473855.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473856.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473857.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473858.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473859.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473880.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473881.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473882.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473883.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473884.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473895.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473896.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473897.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473898.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473899.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473931.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473932.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473933.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473934.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473935.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473941.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473942.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473943.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473944.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473945.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473957.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473958.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473959.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473960.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27473961.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27488213.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27488214.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27488215.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27488216.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27488217.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27488225.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27488226.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27488227.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27488228.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27488229.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27488242.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27488243.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27488244.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27488245.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27488246.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27488268.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27488269.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27488270.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27488271.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27488272.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27488279.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27488280.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27488281.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27488282.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27488283.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27488289.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27488290.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27488291.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27488292.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27488293.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27500277.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27500278.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27500279.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27500280.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27500281.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27500287.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27500288.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27500289.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27500290.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27500291.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27500292.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27500293.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27500294.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27500295.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27500296.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27500322.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27500323.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27500324.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27500325.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27500326.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27500335.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27500336.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27500337.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27500338.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27500339.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503388.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503389.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503390.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503391.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503392.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503403.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503404.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503405.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503406.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503407.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503413.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503414.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503415.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503416.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503417.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503418.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503419.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503420.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503421.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503422.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503423.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503424.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503425.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503426.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503427.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503433.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503434.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503435.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503436.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503437.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503443.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503444.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503445.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503446.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503447.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503453.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503454.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503455.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503456.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503457.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503458.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503459.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503460.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503461.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503462.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503463.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503464.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503465.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503466.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503467.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503468.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503469.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503470.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503471.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503472.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503473.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503474.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503475.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503476.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503477.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503478.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503479.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503480.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503481.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503482.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503483.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503484.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503485.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503486.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27503487.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512372.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512373.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512374.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512375.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512376.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512513.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512514.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512515.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512516.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512517.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512518.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512519.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512520.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512521.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512522.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512523.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512524.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512525.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512526.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512527.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512528.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512529.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512530.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512531.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512532.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512538.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512539.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512540.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512541.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512542.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512544.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512545.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512546.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512547.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512548.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512553.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512554.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512555.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512556.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512557.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512560.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512561.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512562.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512563.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512564.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512566.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512567.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512568.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512569.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512570.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512574.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512575.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512576.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512577.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512578.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512581.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512582.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512583.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512584.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512585.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512587.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512588.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512590.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512591.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512592.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512594.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512595.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512596.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512597.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27512598.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27516875.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27516877.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27516879.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27516881.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27516882.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27516894.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27516895.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27516896.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27516897.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27516898.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27516919.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27516920.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27516921.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27516922.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27516923.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27516934.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27516935.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27516936.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27516937.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27516938.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27516953.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27516956.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27516960.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27516963.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27516966.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27516974.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27516975.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27516976.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27516978.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27516981.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27516986.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27516987.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27516988.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27516989.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27516990.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523315.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523316.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523317.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523318.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523319.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523320.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523321.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523322.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523323.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523324.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523325.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523326.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523327.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523328.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523329.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523330.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523331.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523332.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523333.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523334.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523340.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523341.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523342.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523343.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523344.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523350.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523351.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523352.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523353.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523354.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523360.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523361.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523362.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523363.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523364.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523378.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523379.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523380.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523381.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523382.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523388.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523389.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523390.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523391.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523392.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523408.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523409.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523410.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523411.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523412.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523428.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523429.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523430.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523431.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523432.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523438.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523439.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523440.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523441.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523442.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523448.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523449.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523450.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523451.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523452.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523458.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523459.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523460.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523461.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27523462.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536288.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536289.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536290.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536291.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536292.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536293.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536294.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536295.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536296.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536297.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536298.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536299.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536300.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536301.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536302.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536303.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536304.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536305.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536306.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536307.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536308.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536309.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536310.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536311.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536312.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536313.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536314.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536315.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536316.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536317.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536318.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536319.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536320.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536321.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536322.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536323.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536324.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536325.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536326.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536327.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536328.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536329.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536330.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536331.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536332.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536333.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536334.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536335.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536336.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536337.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536338.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536339.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536340.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536341.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536342.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536343.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536344.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536345.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536346.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536347.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536349.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536350.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536351.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536352.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536353.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536354.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536355.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536356.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536357.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536358.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536359.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536360.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536361.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536362.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536363.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536364.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536365.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536366.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27536367.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549644.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549645.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549646.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549647.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549648.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549923.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549924.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549925.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549926.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549927.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549930.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549931.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549932.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549933.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549934.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549935.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549936.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549937.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549938.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549939.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549940.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549941.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549942.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549943.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549944.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549945.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549946.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549947.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549948.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549949.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549951.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549952.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549953.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549954.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549955.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549956.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549957.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549958.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549959.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549968.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549969.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549970.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549971.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549972.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549988.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549989.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549990.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549991.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27549992.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27550011.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27550012.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27550013.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27550014.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27550015.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27550026.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27550027.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27550028.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27550029.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27550030.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27550074.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27550076.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27550077.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27550079.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27550083.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27550085.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_27550086.mp3
# ...
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358512.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358513.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358529.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358530.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358532.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358534.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358536.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358554.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358555.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358556.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358557.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358558.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358569.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358570.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358571.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358572.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358613.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358614.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358615.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358616.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358617.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358623.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358625.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358629.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358631.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358632.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358638.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358639.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358640.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358641.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358642.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358648.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358649.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358650.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358651.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358652.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358658.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358659.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358660.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358661.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358662.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358668.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358669.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358670.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358671.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358673.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358693.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358694.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358695.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358696.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358697.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358698.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358699.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358700.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358701.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358702.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358713.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358714.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358715.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358716.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358717.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358718.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358719.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358720.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358721.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358722.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358728.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358729.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358730.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358731.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358732.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358733.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358734.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358735.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358736.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358737.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358738.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358739.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358740.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358741.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358742.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358743.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358744.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358745.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358746.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358747.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358748.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358749.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358750.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358751.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358752.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358758.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358759.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358760.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358761.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358762.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358773.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358774.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358775.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358776.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358777.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358779.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358783.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358785.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358786.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31358787.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31366977.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31366978.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31366979.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31366980.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31366981.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31366982.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31366983.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31366984.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31366985.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31366986.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31366987.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31366988.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31366989.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31366990.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31366991.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31366992.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31366993.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31366994.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31366995.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31366996.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31392098.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31392099.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31392100.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31392101.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31392102.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31392108.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31392109.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31392110.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31392111.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31392112.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31392118.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31392119.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31392120.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31392121.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31392122.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31392128.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31392129.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31392130.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31392131.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31392132.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31392386.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31392387.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31392388.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31392389.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31392390.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31392391.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31392392.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31392393.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31392394.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31392395.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31406559.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31406560.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31406561.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31406562.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31406563.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31406614.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31406615.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31406616.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31406617.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31406618.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31419417.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31419418.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31419419.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31419420.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31419421.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31419578.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31419579.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31419580.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31419581.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31419582.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31419594.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31419595.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31419596.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31419597.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31419598.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31419607.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31419608.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31419609.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31419610.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31419611.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31437592.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31437594.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31437596.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31437597.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31437598.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31437601.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31437602.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31437603.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31437604.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31437605.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31437611.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31437612.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31437613.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31437614.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31437615.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31437621.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31437622.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31437623.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31437624.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31437625.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31437646.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31437647.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31437648.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31437649.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31437650.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31437671.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31437672.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31437673.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31437674.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31437675.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31437681.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31437682.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31437683.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31437684.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31437685.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31437696.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31437697.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31437698.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31437699.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31437700.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31482244.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31482245.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31482297.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31482298.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31482299.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31482300.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31482302.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31615093.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31615095.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31615096.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31615098.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31615099.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31745301.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31745302.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31745303.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31745305.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31745306.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31745419.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31745420.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31745421.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31745422.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31745423.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31745484.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31745485.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31745486.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31745487.mp3
# cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_31745488.mp3

# %%
! rm cv-corpus-9.0-2022-04-27-id.tar.gz

# %% [markdown]
# *Install sox before running the CommonVoice Importer.*

# %%
! sudo apt-get install sox libsox-fmt-mp3
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following packages were automatically installed and are no longer required:
#   libnvidia-common-460 nsight-compute-2020.2.0
# Use 'sudo apt autoremove' to remove them.
# The following additional packages will be installed:
#   libid3tag0 libmad0 libmagic-mgc libmagic1 libopencore-amrnb0
#   libopencore-amrwb0 libsox-fmt-alsa libsox-fmt-base libsox3
# Suggested packages:
#   file libsox-fmt-all
# The following NEW packages will be installed:
#   libid3tag0 libmad0 libmagic-mgc libmagic1 libopencore-amrnb0
#   libopencore-amrwb0 libsox-fmt-alsa libsox-fmt-base libsox-fmt-mp3 libsox3
#   sox
# 0 upgraded, 11 newly installed, 0 to remove and 42 not upgraded.
# Need to get 872 kB of archives.
# After this operation, 7,087 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopencore-amrnb0 amd64 0.1.3-2.1 [92.0 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopencore-amrwb0 amd64 0.1.3-2.1 [45.8 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic-mgc amd64 1:5.32-2ubuntu0.4 [184 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic1 amd64 1:5.32-2ubuntu0.4 [68.6 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libid3tag0 amd64 0.15.1b-13 [31.2 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libmad0 amd64 0.15.1b-9ubuntu18.04.1 [64.6 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libsox3 amd64 14.4.2-3ubuntu0.18.04.1 [226 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libsox-fmt-alsa amd64 14.4.2-3ubuntu0.18.04.1 [10.6 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libsox-fmt-base amd64 14.4.2-3ubuntu0.18.04.1 [32.1 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libsox-fmt-mp3 amd64 14.4.2-3ubuntu0.18.04.1 [15.9 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 sox amd64 14.4.2-3ubuntu0.18.04.1 [101 kB]
# Fetched 872 kB in 0s (7,453 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 11.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libopencore-amrnb0:amd64.
# (Reading database ... 155203 files and directories currently installed.)
# Preparing to unpack .../00-libopencore-amrnb0_0.1.3-2.1_amd64.deb ...
# Unpacking libopencore-amrnb0:amd64 (0.1.3-2.1) ...
# Selecting previously unselected package libopencore-amrwb0:amd64.
# Preparing to unpack .../01-libopencore-amrwb0_0.1.3-2.1_amd64.deb ...
# Unpacking libopencore-amrwb0:amd64 (0.1.3-2.1) ...
# Selecting previously unselected package libmagic-mgc.
# Preparing to unpack .../02-libmagic-mgc_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package libmagic1:amd64.
# Preparing to unpack .../03-libmagic1_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package libid3tag0:amd64.
# Preparing to unpack .../04-libid3tag0_0.15.1b-13_amd64.deb ...
# Unpacking libid3tag0:amd64 (0.15.1b-13) ...
# Selecting previously unselected package libmad0:amd64.
# Preparing to unpack .../05-libmad0_0.15.1b-9ubuntu18.04.1_amd64.deb ...
# Unpacking libmad0:amd64 (0.15.1b-9ubuntu18.04.1) ...
# Selecting previously unselected package libsox3:amd64.
# Preparing to unpack .../06-libsox3_14.4.2-3ubuntu0.18.04.1_amd64.deb ...
# Unpacking libsox3:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Selecting previously unselected package libsox-fmt-alsa:amd64.
# Preparing to unpack .../07-libsox-fmt-alsa_14.4.2-3ubuntu0.18.04.1_amd64.deb ...
# Unpacking libsox-fmt-alsa:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Selecting previously unselected package libsox-fmt-base:amd64.
# Preparing to unpack .../08-libsox-fmt-base_14.4.2-3ubuntu0.18.04.1_amd64.deb ...
# Unpacking libsox-fmt-base:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Selecting previously unselected package libsox-fmt-mp3:amd64.
# Preparing to unpack .../09-libsox-fmt-mp3_14.4.2-3ubuntu0.18.04.1_amd64.deb ...
# Unpacking libsox-fmt-mp3:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Selecting previously unselected package sox.
# Preparing to unpack .../10-sox_14.4.2-3ubuntu0.18.04.1_amd64.deb ...
# Unpacking sox (14.4.2-3ubuntu0.18.04.1) ...
# Setting up libid3tag0:amd64 (0.15.1b-13) ...
# Setting up libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Setting up libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Setting up libopencore-amrnb0:amd64 (0.1.3-2.1) ...
# Setting up libmad0:amd64 (0.15.1b-9ubuntu18.04.1) ...
# Setting up libopencore-amrwb0:amd64 (0.1.3-2.1) ...
# Setting up libsox3:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Setting up libsox-fmt-mp3:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Setting up libsox-fmt-base:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Setting up libsox-fmt-alsa:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Setting up sox (14.4.2-3ubuntu0.18.04.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for mime-support (3.60ubuntu1) ...

# %% [markdown]
# To bring this data into a form that DeepSpeech understands, you have to run the CommonVoice v2.0 importer (bin/import_cv2.py):

# %% [markdown]
# #### Preparing Alphabet filter
# Because the transcript quality can be of varying quality. Any words that are not part of the alphabet list will be discarded.
#
# Upload this file in the path of id/alphabet.txt
#
# The files can be downloaded from here https://drive.google.com/file/d/19X2Phj1Ckgon6Tnpj9EEENsgdrqbggw7/view?usp=sharing
#
# or mount your GDrive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Saving it to Google Drive so we don't lose progress
# Out:
# Mounted at /content/drive

# %%
# If error check, for the path of alphabet
# %cd /content/DeepSpeech/
! bin/import_cv2.py ../in/cv-corpus-9.0-2022-04-27/id --filter_alphabet /content/drive/MyDrive/DS_Project_NLP/alphabet.txt
# Out:
# /content/DeepSpeech
# Loading TSV file:  /content/in/cv-corpus-9.0-2022-04-27/id/test.tsv
# Importing mp3 files...
# WARNING: No --validate_label_locale specified, your might end with inconsistent dataset.
# WARNING: No --validate_label_locale specified, your might end with inconsistent dataset.
# Progress |######################################################| 100% completedImported 3608 samples.
# Skipped 14 samples that failed on transcript validation.
# Final amount of imported audio: 4:04:53 from 4:06:01.
# Saving new DeepSpeech-formatted CSV file to:  /content/in/cv-corpus-9.0-2022-04-27/id/clips/test.csv
# Writing CSV file for DeepSpeech.py as:  /content/in/cv-corpus-9.0-2022-04-27/id/clips/test.csv
# Progress |######################################################| 100% completed
# Loading TSV file:  /content/in/cv-corpus-9.0-2022-04-27/id/dev.tsv
# Importing mp3 files...
# WARNING: No --validate_label_locale specified, your might end with inconsistent dataset.
# WARNING: No --validate_label_locale specified, your might end with inconsistent dataset.
# Progress |##################################################### |  98% completedImported 3184 samples.
# Skipped 31 samples that failed on transcript validation.
# Skipped 3 samples that were longer than 10 seconds.
# Final amount of imported audio: 3:40:15 from 3:43:53.
# Saving new DeepSpeech-formatted CSV file to:  /content/in/cv-corpus-9.0-2022-04-27/id/clips/dev.csv
# Writing CSV file for DeepSpeech.py as:  /content/in/cv-corpus-9.0-2022-04-27/id/clips/dev.csv
# Progress |######################################################| 100% completed
# Loading TSV file:  /content/in/cv-corpus-9.0-2022-04-27/id/train.tsv
# Importing mp3 files...
# WARNING: No --validate_label_locale specified, your might end with inconsistent dataset.
# WARNING: No --validate_label_locale specified, your might end with inconsistent dataset.
# Progress |##################################################### |  98% completedImported 4855 samples.
# Skipped 170 samples that failed on transcript validation.
# Skipped 18 samples that were longer than 10 seconds.
# Final amount of imported audio: 7:24:28 from 7:44:20.
# Saving new DeepSpeech-formatted CSV file to:  /content/in/cv-corpus-9.0-2022-04-27/id/clips/train.csv
# Writing CSV file for DeepSpeech.py as:  /content/in/cv-corpus-9.0-2022-04-27/id/clips/train.csv
# Progress |######################################################| 100% completed
# Loading TSV file:  /content/in/cv-corpus-9.0-2022-04-27/id/validated.tsv
# Importing mp3 files...
# WARNING: No --validate_label_locale specified, your might end with inconsistent dataset.
# WARNING: No --validate_label_locale specified, your might end with inconsistent dataset.
# Progress |######################################################| 100% completedImported 22873 samples.
# Skipped 234 samples that failed on transcript validation.
# Skipped 25 samples that were longer than 10 seconds.
# Final amount of imported audio: 27:45:58 from 28:12:53.
# Saving new DeepSpeech-formatted CSV file to:  /content/in/cv-corpus-9.0-2022-04-27/id/clips/validated.csv
# Writing CSV file for DeepSpeech.py as:  /content/in/cv-corpus-9.0-2022-04-27/id/clips/validated.csv
# Progress |######################################################| 100% completed
# Saving new DeepSpeech-formatted CSV file to:  /content/in/cv-corpus-9.0-2022-04-27/id/clips/train-all.csv
# Writing CSV file for DeepSpeech.py as:  /content/in/cv-corpus-9.0-2022-04-27/id/clips/train-all.csv
# Progress |######################################################| 100% completed
# Loading TSV file:  /content/in/cv-corpus-9.0-2022-04-27/id/other.tsv
# Importing mp3 files...
# WARNING: No --validate_label_locale specified, your might end with inconsistent dataset.
# WARNING: No --validate_label_locale specified, your might end with inconsistent dataset.
# Progress |######################################################| 100% completedImported 22730 samples.
# Skipped 50 samples that failed on transcript validation.
# Skipped 7 samples that were longer than 10 seconds.
# Final amount of imported audio: 23:33:15 from 23:38:35.
# Saving new DeepSpeech-formatted CSV file to:  /content/in/cv-corpus-9.0-2022-04-27/id/clips/other.csv
# Writing CSV file for DeepSpeech.py as:  /content/in/cv-corpus-9.0-2022-04-27/id/clips/other.csv
# Progress |######################################################| 100% completed
# Progress |######################################################| 100% completed
# Progress |######################################################| 100% completed
# Progress |######################################################| 100% completed
# Progress |######################################################| 100% completed
# Progress |######################################################| 100% completed

# %% [markdown]
# ### Simple Training of Model using only CV

# %%
# To update with latest checkpoint, you can download latest checkpoint and upload it in the right folder
# put it into load_checkpoint

# %%
# %cd /content/DeepSpeech/
! python3 DeepSpeech.py \
  --train_files /content/in/cv-corpus-9.0-2022-04-27/id/clips/train.csv \
  --dev_files /content/in/cv-corpus-9.0-2022-04-27/id/clips/dev.csv \
  --test_files /content/in/cv-corpus-9.0-2022-04-27/id/clips/test.csv \
  --train_batch_size 1 \
  --test_batch_size 1 \
  --n_hidden 100 \
  --epochs 20 \
  --checkpoint_dir /content/drive/MyDrive/DS_Project_NLP/checkpoint \
  --export_dir /content/drive/MyDrive/DS_Project_NLP/model
# Out:
# /content/DeepSpeech
# I Loading best validating checkpoint from /content/drive/MyDrive/DS_Project_NLP/checkpoint/best_dev-315575
# I Loading variable from checkpoint: beta1_power
# I Loading variable from checkpoint: beta2_power
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias/Adam
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias/Adam_1
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel/Adam
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel/Adam_1
# I Loading variable from checkpoint: global_step
# I Loading variable from checkpoint: layer_1/bias
# I Loading variable from checkpoint: layer_1/bias/Adam
# I Loading variable from checkpoint: layer_1/bias/Adam_1
# I Loading variable from checkpoint: layer_1/weights
# I Loading variable from checkpoint: layer_1/weights/Adam
# I Loading variable from checkpoint: layer_1/weights/Adam_1
# I Loading variable from checkpoint: layer_2/bias
# I Loading variable from checkpoint: layer_2/bias/Adam
# I Loading variable from checkpoint: layer_2/bias/Adam_1
# I Loading variable from checkpoint: layer_2/weights
# I Loading variable from checkpoint: layer_2/weights/Adam
# I Loading variable from checkpoint: layer_2/weights/Adam_1
# I Loading variable from checkpoint: layer_3/bias
# I Loading variable from checkpoint: layer_3/bias/Adam
# I Loading variable from checkpoint: layer_3/bias/Adam_1
# I Loading variable from checkpoint: layer_3/weights
# I Loading variable from checkpoint: layer_3/weights/Adam
# I Loading variable from checkpoint: layer_3/weights/Adam_1
# I Loading variable from checkpoint: layer_5/bias
# I Loading variable from checkpoint: layer_5/bias/Adam
# I Loading variable from checkpoint: layer_5/bias/Adam_1
# I Loading variable from checkpoint: layer_5/weights
# I Loading variable from checkpoint: layer_5/weights/Adam
# I Loading variable from checkpoint: layer_5/weights/Adam_1
# I Loading variable from checkpoint: layer_6/bias
# I Loading variable from checkpoint: layer_6/bias/Adam
# I Loading variable from checkpoint: layer_6/bias/Adam_1
# I Loading variable from checkpoint: layer_6/weights
# I Loading variable from checkpoint: layer_6/weights/Adam
# I Loading variable from checkpoint: layer_6/weights/Adam_1
# I Loading variable from checkpoint: learning_rate
# I STARTING Optimization
# Epoch 0 |   Training | Elapsed Time: 0:04:45 | Steps: 4855 | Loss: 58.029196
# Epoch 0 | Validation | Elapsed Time: 0:02:39 | Steps: 3184 | Loss: 89.666472 | Dataset: /content/in/cv-corpus-9.0-2022-04-27/id/clips/dev.csv
# I Saved new best validating model with loss 89.666472 to: /content/drive/MyDrive/DS_Project_NLP/checkpoint/best_dev-320430
# --------------------------------------------------------------------------------
# Epoch 1 |   Training | Elapsed Time: 0:04:40 | Steps: 4855 | Loss: 57.661532
# Epoch 1 | Validation | Elapsed Time: 0:02:39 | Steps: 3184 | Loss: 88.771816 | Dataset: /content/in/cv-corpus-9.0-2022-04-27/id/clips/dev.csv
# I Saved new best validating model with loss 88.771816 to: /content/drive/MyDrive/DS_Project_NLP/checkpoint/best_dev-325285
# --------------------------------------------------------------------------------
# Epoch 2 |   Training | Elapsed Time: 0:04:41 | Steps: 4855 | Loss: 58.162735
# Epoch 2 | Validation | Elapsed Time: 0:02:39 | Steps: 3184 | Loss: 90.430770 | Dataset: /content/in/cv-corpus-9.0-2022-04-27/id/clips/dev.csv
# --------------------------------------------------------------------------------
# Epoch 3 |   Training | Elapsed Time: 0:04:40 | Steps: 4855 | Loss: 58.140497
# Epoch 3 | Validation | Elapsed Time: 0:02:39 | Steps: 3184 | Loss: 90.666485 | Dataset: /content/in/cv-corpus-9.0-2022-04-27/id/clips/dev.csv
# --------------------------------------------------------------------------------
# Epoch 4 |   Training | Elapsed Time: 0:04:41 | Steps: 4855 | Loss: 57.973658
# Epoch 4 | Validation | Elapsed Time: 0:02:39 | Steps: 3184 | Loss: 92.197041 | Dataset: /content/in/cv-corpus-9.0-2022-04-27/id/clips/dev.csv
# --------------------------------------------------------------------------------
# Epoch 5 |   Training | Elapsed Time: 0:04:41 | Steps: 4855 | Loss: 58.606254
# Epoch 5 | Validation | Elapsed Time: 0:02:39 | Steps: 3184 | Loss: 90.663084 | Dataset: /content/in/cv-corpus-9.0-2022-04-27/id/clips/dev.csv
# --------------------------------------------------------------------------------
# Epoch 6 |   Training | Elapsed Time: 0:04:40 | Steps: 4855 | Loss: 58.226963
# Epoch 6 | Validation | Elapsed Time: 0:02:39 | Steps: 3184 | Loss: 88.675689 | Dataset: /content/in/cv-corpus-9.0-2022-04-27/id/clips/dev.csv
# I Saved new best validating model with loss 88.675689 to: /content/drive/MyDrive/DS_Project_NLP/checkpoint/best_dev-349560
# --------------------------------------------------------------------------------
# Epoch 7 |   Training | Elapsed Time: 0:04:41 | Steps: 4855 | Loss: 59.407453
# Epoch 7 | Validation | Elapsed Time: 0:02:39 | Steps: 3184 | Loss: 91.023006 | Dataset: /content/in/cv-corpus-9.0-2022-04-27/id/clips/dev.csv
# --------------------------------------------------------------------------------
# Epoch 8 |   Training | Elapsed Time: 0:04:41 | Steps: 4855 | Loss: 59.090662
# Epoch 8 | Validation | Elapsed Time: 0:02:39 | Steps: 3184 | Loss: 91.487375 | Dataset: /content/in/cv-corpus-9.0-2022-04-27/id/clips/dev.csv
# --------------------------------------------------------------------------------
# Epoch 9 |   Training | Elapsed Time: 0:04:41 | Steps: 4855 | Loss: 58.848990
# Epoch 9 | Validation | Elapsed Time: 0:02:39 | Steps: 3184 | Loss: 90.697573 | Dataset: /content/in/cv-corpus-9.0-2022-04-27/id/clips/dev.csv
# --------------------------------------------------------------------------------
# Epoch 10 |   Training | Elapsed Time: 0:04:40 | Steps: 4855 | Loss: 58.662847
# Epoch 10 | Validation | Elapsed Time: 0:02:39 | Steps: 3184 | Loss: 90.314205 | Dataset: /content/in/cv-corpus-9.0-2022-04-27/id/clips/dev.csv
# --------------------------------------------------------------------------------
# Epoch 11 |   Training | Elapsed Time: 0:04:41 | Steps: 4855 | Loss: 58.957646
# Epoch 11 | Validation | Elapsed Time: 0:02:39 | Steps: 3184 | Loss: 89.207029 | Dataset: /content/in/cv-corpus-9.0-2022-04-27/id/clips/dev.csv
# --------------------------------------------------------------------------------
# Epoch 12 |   Training | Elapsed Time: 0:04:40 | Steps: 4855 | Loss: 58.565965
# Epoch 12 | Validation | Elapsed Time: 0:02:39 | Steps: 3184 | Loss: 91.025095 | Dataset: /content/in/cv-corpus-9.0-2022-04-27/id/clips/dev.csv
# --------------------------------------------------------------------------------
# Epoch 13 |   Training | Elapsed Time: 0:04:40 | Steps: 4855 | Loss: 58.871833
# Epoch 13 | Validation | Elapsed Time: 0:02:39 | Steps: 3184 | Loss: 88.700134 | Dataset: /content/in/cv-corpus-9.0-2022-04-27/id/clips/dev.csv
# --------------------------------------------------------------------------------
# Epoch 14 |   Training | Elapsed Time: 0:04:40 | Steps: 4855 | Loss: 58.885571
# Epoch 14 | Validation | Elapsed Time: 0:02:39 | Steps: 3184 | Loss: 88.737443 | Dataset: /content/in/cv-corpus-9.0-2022-04-27/id/clips/dev.csv
# --------------------------------------------------------------------------------
# Epoch 15 |   Training | Elapsed Time: 0:04:41 | Steps: 4855 | Loss: 58.496283
# Epoch 15 | Validation | Elapsed Time: 0:02:39 | Steps: 3184 | Loss: 91.463667 | Dataset: /content/in/cv-corpus-9.0-2022-04-27/id/clips/dev.csv
# --------------------------------------------------------------------------------
# Epoch 16 |   Training | Elapsed Time: 0:04:44 | Steps: 4855 | Loss: 59.492691
# Epoch 16 | Validation | Elapsed Time: 0:01:56 | Steps: 2319 | Loss: 75.545911 | Dataset: /content/in/cv-corpus-9.0-2022-04-27/id/clips/dev.csvE The following files caused an infinite (or NaN) loss: /content/in/cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_25971936.wav
# Epoch 16 | Validation | Elapsed Time: 0:02:39 | Steps: 3184 | Loss: inf | Dataset: /content/in/cv-corpus-9.0-2022-04-27/id/clips/dev.csv
# --------------------------------------------------------------------------------
# Epoch 17 |   Training | Elapsed Time: 0:04:41 | Steps: 4855 | Loss: 59.441738
# Epoch 17 | Validation | Elapsed Time: 0:02:39 | Steps: 3184 | Loss: 90.819782 | Dataset: /content/in/cv-corpus-9.0-2022-04-27/id/clips/dev.csv
# --------------------------------------------------------------------------------
# Epoch 18 |   Training | Elapsed Time: 0:04:42 | Steps: 4855 | Loss: 59.076702
# Epoch 18 | Validation | Elapsed Time: 0:02:39 | Steps: 3184 | Loss: 91.080156 | Dataset: /content/in/cv-corpus-9.0-2022-04-27/id/clips/dev.csv
# --------------------------------------------------------------------------------
# Epoch 19 |   Training | Elapsed Time: 0:04:41 | Steps: 4855 | Loss: 58.753137
# Epoch 19 | Validation | Elapsed Time: 0:02:39 | Steps: 3184 | Loss: 90.372452 | Dataset: /content/in/cv-corpus-9.0-2022-04-27/id/clips/dev.csv
# --------------------------------------------------------------------------------
# I FINISHED optimization in 2:27:15.670246
# I Loading best validating checkpoint from /content/drive/MyDrive/DS_Project_NLP/checkpoint/best_dev-349560
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel
# I Loading variable from checkpoint: global_step
# I Loading variable from checkpoint: layer_1/bias
# I Loading variable from checkpoint: layer_1/weights
# I Loading variable from checkpoint: layer_2/bias
# I Loading variable from checkpoint: layer_2/weights
# I Loading variable from checkpoint: layer_3/bias
# I Loading variable from checkpoint: layer_3/weights
# I Loading variable from checkpoint: layer_5/bias
# I Loading variable from checkpoint: layer_5/weights
# I Loading variable from checkpoint: layer_6/bias
# I Loading variable from checkpoint: layer_6/weights
# Testing model on /content/in/cv-corpus-9.0-2022-04-27/id/clips/test.csv
# Test epoch | Steps: 3608 | Elapsed Time: 1:02:13
# Test on /content/in/cv-corpus-9.0-2022-04-27/id/clips/test.csv - WER: 0.994727, CER: 0.512534, loss: 73.700699
# --------------------------------------------------------------------------------
# Best WER:
# --------------------------------------------------------------------------------
# WER: 0.400000, CER: 0.321429, loss: 30.577381
#  - wav: file:///content/in/cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_20891784.wav
#  - src: "dia menolak rencana baru itu"
#  - res: "dia bedurgaterencinda baru itu"
# --------------------------------------------------------------------------------
# WER: 0.400000, CER: 0.269231, loss: 26.244564
#  - wav: file:///content/in/cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_19258420.wav
#  - src: "apa yang akan kamu lakukan"
#  - res: "apa yang akan kabera uplan"
# --------------------------------------------------------------------------------
# WER: 0.400000, CER: 0.148148, loss: 14.654359
#  - wav: file:///content/in/cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_19785562.wav
#  - src: "hari ini saya tidak sarapan"
#  - res: "hari ini sayatuga sarapan"
# --------------------------------------------------------------------------------
# WER: 0.500000, CER: 0.272727, loss: 47.319477
#  - wav: file:///content/in/cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_20388000.wav
#  - src: "kantor pos ada di sebelah stasiun"
#  - res: "antak pos ada di sebastasi"
# --------------------------------------------------------------------------------
# WER: 0.500000, CER: 0.256410, loss: 37.290348
#  - wav: file:///content/in/cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_19653081.wav
#  - src: "kedai kopi itu ada di sebelah toko buku"
#  - res: "kedai popi itu ada di sebat tepeputu"
# --------------------------------------------------------------------------------
# Median WER:
# --------------------------------------------------------------------------------
# WER: 1.000000, CER: 0.611111, loss: 71.250153
#  - wav: file:///content/in/cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_24931172.wav
#  - src: "nenek pak kobayashi memakai kacamata"
#  - res: "inin papumaisi menaki tecimatat an "
# --------------------------------------------------------------------------------
# WER: 1.000000, CER: 0.428571, loss: 71.239883
#  - wav: file:///content/in/cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_19986813.wav
#  - src: "anak laki laki itu memiliki reputasi yang lumayan"
#  - res: "ana paturapito monlitirapetasyang emayan"
# --------------------------------------------------------------------------------
# WER: 1.000000, CER: 0.571429, loss: 71.114296
#  - wav: file:///content/in/cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_20953165.wav
#  - src: "apakah ini mobil anda"
#  - res: "a ako ah alana"
# --------------------------------------------------------------------------------
# WER: 1.000000, CER: 0.479167, loss: 71.108307
#  - wav: file:///content/in/cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_20483312.wav
#  - src: "aku pernah ingin menjadi seorang astronom fisika"
#  - res: "apola dana inan mengagin sawara asperonam fifia"
# --------------------------------------------------------------------------------
# WER: 1.000000, CER: 0.447368, loss: 71.090027
#  - wav: file:///content/in/cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_19062378.wav
#  - src: "ikhlas itu urusan hamba denga tuhannya"
#  - res: "isaseta basanam batengan tehanya"
# --------------------------------------------------------------------------------
# Worst WER:
# --------------------------------------------------------------------------------
# WER: 3.000000, CER: 1.520000, loss: 138.271164
#  - wav: file:///content/in/cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_20953901.wav
#  - src: "sekarang pukul tujuh pagi"
#  - res: "eno a dnanankaka da dek i u ae eta aaaleju ir ke"
# --------------------------------------------------------------------------------
# WER: 3.000000, CER: 3.000000, loss: 24.678768
#  - wav: file:///content/in/cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_23920010.wav
#  - src: "dua"
#  - res: "e lel ler"
# --------------------------------------------------------------------------------
# WER: 3.000000, CER: 1.200000, loss: 19.240841
#  - wav: file:///content/in/cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_22650889.wav
#  - src: "tujuh"
#  - res: "tunki u u"
# --------------------------------------------------------------------------------
# WER: 3.000000, CER: 1.000000, loss: 18.299789
#  - wav: file:///content/in/cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_22546523.wav
#  - src: "tidak"
#  - res: "un i an"
# --------------------------------------------------------------------------------
# WER: 4.000000, CER: 1.857143, loss: 38.604431
#  - wav: file:///content/in/cv-corpus-9.0-2022-04-27/id/clips/common_voice_id_20954083.wav
#  - src: "makasih"
#  - res: "ols para as eter"
# --------------------------------------------------------------------------------
# I Exporting the model...
# I Loading best validating checkpoint from /content/drive/MyDrive/DS_Project_NLP/checkpoint/best_dev-349560
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel
# I Loading variable from checkpoint: layer_1/bias
# I Loading variable from checkpoint: layer_1/weights
# I Loading variable from checkpoint: layer_2/bias
# I Loading variable from checkpoint: layer_2/weights
# I Loading variable from checkpoint: layer_3/bias
# I Loading variable from checkpoint: layer_3/weights
# I Loading variable from checkpoint: layer_5/bias
# I Loading variable from checkpoint: layer_5/weights
# I Loading variable from checkpoint: layer_6/bias
# I Loading variable from checkpoint: layer_6/weights
# I Models exported at /content/drive/MyDrive/DS_Project_NLP/model
# I Model metadata file saved to /content/drive/MyDrive/DS_Project_NLP/model/author_model_0.0.1.md. Before submitting the exported model for publishing make sure all information in the metadata file is correct, and complete the URL fields.

# %% [markdown]
# ### STOP HERE
